# %% [markdown]
# ## This notebook walks through locally running mcad and ma bots using naive bot manager

# %%
# import necessary libaries 
# %reload_ext autoreload
# %autoreload 2
import os
os.chdir('..')

from scripts.apimanagers import APImanager
from scripts.assets import Account, Stock
from scripts.botmanagers import Stocks_manager_naive
from scripts.bots import Moving_average_bot, Macd_bot

import numpy as np
import pandas as pd
import alpaca_trade_api as tradeapi
from alpaca_trade_api.rest import TimeFrame
import datetime
import time

# %% [markdown]
# ### Initialization

# %%
# global variables
API_KEY = "PKW4QJCBVY9V19D2ACFX"#<your API_KEY here>
SECRET_KEY = "Qn660Zot3VSUOFFUd8RhbitHkZdnSrcAZqudzItj"#<your SECRET_KEY here>
CUR_TIME_DELAYED = (datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(minutes=16))  # 16 minutes delay of current time for bars data
CUR_TIME = (datetime.datetime.now(datetime.timezone.utc))  # 15 minutes delay of current time for bars data
print(CUR_TIME_DELAYED)
# Out:
# 2021-06-16 17:55:04.518319+00:00

# %%
# create API manager
API_manager = APImanager(API_KEY, SECRET_KEY)

# %%
# get some past data for initialization. Let's look at APPL and AMD for this demonstration
hour_bar_apple, hour_bar_apple_t = API_manager.get_bar("AAPL", TimeFrame.Hour, "2021-06-08", CUR_TIME_DELAYED.astimezone().isoformat())
hour_bar_amd, hour_bar_amd_t = API_manager.get_bar("AMD", TimeFrame.Hour, "2021-06-08", CUR_TIME_DELAYED.astimezone().isoformat())
minute_bar_bili, minute_bar_bili_t = API_manager.get_bar("BILI", TimeFrame.Minute, (CUR_TIME_DELAYED - datetime.timedelta(minutes=500)).astimezone().isoformat(), CUR_TIME_DELAYED.astimezone().isoformat())

#get current price of the stock for initialization.
cur_price_apple = API_manager.get_price("AAPL")
cur_price_amd = API_manager.get_price("AMD")
cur_price_bili = API_manager.get_price("BILI")

#print(minute_bar_bili, cur_price_bili, minute_bar_bili_t)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-9-c1727ec1b942> in <module>
#       2 #hour_bar_apple, hour_bar_apple_t = API_manager.get_bar("AAPL", TimeFrame.Hour, "2021-06-08", CUR_TIME_DELAYED.astimezone().isoformat())
#       3 #hour_bar_amd, hour_bar_amd_t = API_manager.get_bar("AMD", TimeFrame.Hour, "2021-06-08", CUR_TIME_DELAYED.astimezone().isoformat())
# ----> 4 minute_bar_bili, minute_bar_bili_t = API_manager.get_bar("BILI", TimeFrame.Minute, (CUR_TIME_DELAYED - datetime.timedelta(minutes=500)).astimezone().isoformat(), CUR_TIME_DELAYED.astimezone().isoformat())
#       5
#       6 #get current price of the stock for initialization.
#
# ~\Documents\GitHub\alpaca_bot\scripts\apimanagers.py in get_bar(self, symbol, timestep, start, end, price_type)
#      44         - a list of time associated with each price
#      45       """
# ---> 46       bars = self.api.get_bars(symbol, timestep, start, end, adjustment='raw').df
#      47       if bars.empty:
#      48           return [],[]
#
# ~\anaconda3\lib\site-packages\alpaca_trade_api\rest.py in get_bars(self, symbol, timeframe, start, end, adjustment, limit)
#     629                  limit: int = None,
#     630                  ) -> BarsV2:
# --> 631         bars = list(self.get_bars_iter(symbol,
#     632                                        timeframe,
#     633                                        start,
#
# ~\anaconda3\lib\site-packages\alpaca_trade_api\rest.py in get_bars_iter(self, symbol, timeframe, start, end, adjustment, limit, raw)
#     615                                  adjustment=adjustment,
#     616                                  start=start, end=end, limit=limit)
# --> 617         for bar in bars:
#     618             if raw:
#     619                 yield bar
#
# ~\anaconda3\lib\site-packages\alpaca_trade_api\rest.py in _data_get_v2(self, endpoint, symbol, **kwargs)
#     539             data['limit'] = actual_limit
#     540             data['page_token'] = page_token
# --> 541             resp = self.data_get('/stocks/{}/{}'.format(symbol, endpoint),
#     542                                  data=data, api_version='v2')
#     543             items = resp.get(endpoint, [])
#
# ~\anaconda3\lib\site-packages\alpaca_trade_api\rest.py in data_get(self, path, data, api_version)
#     191     def data_get(self, path, data=None, api_version='v1'):
#     192         base_url: URL = get_data_url()
# --> 193         return self._request(
#     194             'GET', path, data, base_url=base_url, api_version=api_version,
#     195         )
#
# ~\anaconda3\lib\site-packages\alpaca_trade_api\rest.py in _request(self, method, path, data, base_url, api_version)
#     138         while retry >= 0:
#     139             try:
# --> 140                 return self._one_request(method, url, opts, retry)
#     141             except RetryException:
#     142                 retry_wait = self._retry_wait
#
# ~\anaconda3\lib\site-packages\alpaca_trade_api\rest.py in _one_request(self, method, url, opts, retry)
#     159         resp = self._session.request(method, url, **opts)
#     160         try:
# --> 161             resp.raise_for_status()
#     162         except HTTPError as http_error:
#     163             # retry if we hit Rate Limit
#
# ~\anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     939
#     940         if http_error_msg:
# --> 941             raise HTTPError(http_error_msg, response=self)
#     942
#     943     def close(self):
#
# HTTPError: 403 Client Error: Forbidden for url: https://data.alpaca.markets/v2/stocks/BILI/bars?timeframe=1Min&adjustment=raw&start=2021-06-16T05%3A35%3A04.518319-04%3A00&end=2021-06-16T13%3A55%3A04.518319-04%3A00

# %%
# create stock objects
APPL_hour = Stock("AAPL", cur_price_apple, CUR_TIME_DELAYED, hour_bar_apple, TimeFrame.Hour, hour_bar_apple_t[0])
AMD_hour = Stock("AMD", cur_price_amd, CUR_TIME_DELAYED, hour_bar_amd, TimeFrame.Hour, hour_bar_amd_t[0])
BILI_minute = Stock("BILI", cur_price_bili, CUR_TIME_DELAYED, minute_bar_bili, TimeFrame.Minute, minute_bar_bili_t[0])
STOCKS = [APPL_hour, AMD_hour, BILI_minute]

# %%
# create bot objects. Give each bot let's say $20,000 asset for trading
BOT_AAPL_ma_hour = Moving_average_bot(APPL_hour, 20000)
BOT_AMD_macd_hour = Macd_bot(AMD_hour, 20000)
BOT_BILI_macd_minute = Macd_bot(BILI_minute, 20000)
BOTS = [BOT_AAPL_ma_hour, BOT_AMD_macd_hour, BOT_BILI_macd_minute]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fa7ff325a68a> in <module>
#       1 # create bot objects. Give each bot let's say $20,000 asset for trading
# ----> 2 BOT_AAPL_ma_hour = Moving_average_bot(APPL_hour, 20000)
#       3 BOT_AMD_macd_hour = Macd_bot(AMD_hour, 20000)
#       4 BOT_BILI_macd_minute = Macd_bot(BILI_minute, 20000)
#       5 BOTS = [BOT_AAPL_ma_hour, BOT_AMD_macd_hour, BOT_BILI_macd_minute]
#
# NameError: name 'APPL_hour' is not defined

# %%
# create the bot manager
bot_manager = Stocks_manager_naive(BOTS, None)

# %%
# print some prices for sanity check
APPL_hour.plot_price(25)
AMD_hour.plot_price(25)
BILI_minute.plot_price(25)

# %% [markdown]
# ### The Main Loop

# %%
def update_utils():
    global CUR_TIME_DELAYED, CUR_TIME
    CUR_TIME_DELAYED = (datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(minutes=16))  # 16 minutes delay of current time for bars data
    CUR_TIME = (datetime.datetime.now(datetime.timezone.utc))  # 15 minutes delay of current time for bars data

def update_stocks(passed_minutes = 15): # assumes 15 minutes has passed since the last update
    for s in STOCKS:
        symbol = s.symbol
        timeframe = s.timeframe
        cur_price = API_manager.get_price(symbol)
        bar, bar_t = API_manager.get_bar(symbol, timeframe, (CUR_TIME_DELAYED - datetime.timedelta(minutes=passed_minutes)).astimezone().isoformat(), CUR_TIME_DELAYED.astimezone().isoformat())
        #print(bar, bar_t)
        s.update(cur_price, bar, bar_t, CUR_TIME_DELAYED)

def complete_actions(action_dict):
    for symbol in action_dict.keys():
        shares = action_dict[symbol]
        if shares < 0:
            #sell
            try:
                API_manager.sell_stocks(symbol, abs(shares))
                print("-> Successfully sold", abs(shares), "of", symbol,".")
            except Exception as e:
                print("-> Selling", abs(shares), "of", symbol,"failed.")
                print(e)
        if shares > 0:
            #buy
            try:
                API_manager.buy_stocks(symbol, abs(shares))
                print("-> Successfully bought", abs(shares), "of", symbol,".")
            except Exception as e:
                print("-> Buying", abs(shares), "of", symbol,"failed.")
                print(e)

# %%
interation = 1
while True:    
    print("*** Iteration", interation)
    update_utils() # update the utility global variables such as CUR_TIME
    update_stocks() # update the stock objects
    print("Current time is", CUR_TIME, ". The delayed time is", CUR_TIME_DELAYED)
    action_dict = bot_manager.make_decision()
    complete_actions(action_dict)
    time.sleep(60) #make decision every 60 seconds
    print(" ")
    interation +=1
# Out:
# *** Iteration 1
# Current time is 2021-06-16 17:22:35.823151+00:00 . The delayed time is 2021-06-16 17:06:35.823151+00:00
# -> buying BILI for 181 shares for $ 110.42 per share
# -> Successfully bought 181 of BILI .
#
# *** Iteration 2
# Current time is 2021-06-16 17:23:36.547775+00:00 . The delayed time is 2021-06-16 17:07:36.547775+00:00
# --- No action performed at this time ---
#
# *** Iteration 3
# Current time is 2021-06-16 17:24:36.877880+00:00 . The delayed time is 2021-06-16 17:08:36.877880+00:00
# --- No action performed at this time ---
#
# *** Iteration 4
# Current time is 2021-06-16 17:25:37.263894+00:00 . The delayed time is 2021-06-16 17:09:37.263894+00:00
# --- No action performed at this time ---
#
# *** Iteration 5
# Current time is 2021-06-16 17:26:37.569733+00:00 . The delayed time is 2021-06-16 17:10:37.569733+00:00
# --- No action performed at this time ---
#
# *** Iteration 6
# Current time is 2021-06-16 17:27:37.896007+00:00 . The delayed time is 2021-06-16 17:11:37.896007+00:00
# --- No action performed at this time ---
#
# *** Iteration 7
# Current time is 2021-06-16 17:28:38.192595+00:00 . The delayed time is 2021-06-16 17:12:38.192595+00:00
# --- No action performed at this time ---
#
# *** Iteration 8
# Current time is 2021-06-16 17:29:38.517248+00:00 . The delayed time is 2021-06-16 17:13:38.517248+00:00
# --- No action performed at this time ---
