# %% [markdown]
# ## This notebook walks through locally running mcad and ma bots using naive bot manager

# %%
# import necessary libaries 
# %reload_ext autoreload
# %autoreload 2
import os
os.chdir('..')

from scripts.apimanagers import APImanager
from scripts.assets import Account, Stock
from scripts.botmanagers import Stocks_manager_naive
from scripts.bots import Moving_average_bot, Macd_bot

import numpy as np
import pandas as pd
import alpaca_trade_api as tradeapi
from alpaca_trade_api.rest import TimeFrame
import datetime
import time

# %% [markdown]
# ### Initialization

# %%
# global variables
API_KEY = "PKK2E9F03LXMTKJBENEO"#<your API_KEY here>
SECRET_KEY = "YTKQgq5ipZUHxOlpkNvYnK7bSlHkQnkbtCoLpQY5"#<your SECRET_KEY here>
CUR_TIME_DELAYED = (datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(minutes=16))  # 16 minutes delay of current time for bars data
CUR_TIME = (datetime.datetime.now(datetime.timezone.utc))  # 15 minutes delay of current time for bars data
print(CUR_TIME_DELAYED)
# Out:
# 2021-06-16 16:03:10.131331+00:00

# %%
# create API manager
API_manager = APImanager(API_KEY, SECRET_KEY)

# %%
# get some past data for initialization. Let's look at APPL and AMD for this demonstration
hour_bar_apple, hour_bar_apple_t = API_manager.get_bar("AAPL", TimeFrame.Hour, "2021-06-08", CUR_TIME_DELAYED.astimezone().isoformat())
hour_bar_amd, hour_bar_amd_t = API_manager.get_bar("AMD", TimeFrame.Hour, "2021-06-08", CUR_TIME_DELAYED.astimezone().isoformat())
minute_bar_bili, minute_bar_bili_t = API_manager.get_bar("BILI", TimeFrame.Minute, (CUR_TIME_DELAYED - datetime.timedelta(minutes=500)).astimezone().isoformat(), CUR_TIME_DELAYED.astimezone().isoformat())

#get current price of the stock for initialization.
cur_price_apple = API_manager.get_price("AAPL")
cur_price_amd = API_manager.get_price("AMD")
cur_price_bili = API_manager.get_price("BILI")

#print(minute_bar_bili, cur_price_bili, minute_bar_bili_t)

# %%
# create stock objects
APPL_hour = Stock("AAPL", cur_price_apple, CUR_TIME_DELAYED, hour_bar_apple, TimeFrame.Hour, hour_bar_apple_t[0])
AMD_hour = Stock("AMD", cur_price_amd, CUR_TIME_DELAYED, hour_bar_amd, TimeFrame.Hour, hour_bar_amd_t[0])
BILI_minute = Stock("BILI", cur_price_bili, CUR_TIME_DELAYED, minute_bar_bili, TimeFrame.Minute, minute_bar_bili_t[0])
STOCKS = [APPL_hour, AMD_hour, BILI_minute]

# %%
# create bot objects. Give each bot let's say $200,000 asset for trading
BOT_AAPL_ma_hour = Moving_average_bot(APPL_hour, 200000)
BOT_AMD_macd_hour = Macd_bot(AMD_hour, 200000)
BOT_BILI_macd_minute = Macd_bot(BILI_minute, 200000)
BOTS = [BOT_AAPL_ma_hour, BOT_AMD_macd_hour, BOT_BILI_macd_minute]

# %%
# create the bot manager
bot_manager = Stocks_manager_naive(BOTS, None)

# %%
# print some prices for sanity check
APPL_hour.plot_price(25)
AMD_hour.plot_price(25)
BILI_minute.plot_price(25)

# %% [markdown]
# ### The Main Loop

# %%
def update_utils():
    global CUR_TIME_DELAYED, CUR_TIME
    CUR_TIME_DELAYED = (datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(minutes=16))  # 16 minutes delay of current time for bars data
    CUR_TIME = (datetime.datetime.now(datetime.timezone.utc))  # 15 minutes delay of current time for bars data

def update_stocks(passed_minutes = 15): # assumes 15 minutes has passed since the last update
    for s in STOCKS:
        symbol = s.symbol
        timeframe = s.timeframe
        cur_price = API_manager.get_price(symbol)
        bar, bar_t = API_manager.get_bar(symbol, timeframe, (CUR_TIME_DELAYED - datetime.timedelta(minutes=passed_minutes)).astimezone().isoformat(), CUR_TIME_DELAYED.astimezone().isoformat())
        #print(bar, bar_t)
        s.update(cur_price, bar, bar_t, CUR_TIME_DELAYED)

def complete_actions(action_dict):
    for symbol in action_dict.keys():
        shares = action_dict[symbol]
        if shares < 0:
            #sell
            try:
                API_manager.sell_stocks(symbol, abs(shares))
                print("-> Successfully sold", abs(shares), "of", symbol,".")
            except Exception as e:
                print("-> Selling", abs(shares), "of", symbol,"failed.")
                print(e)
        if shares > 0:
            #buy
            try:
                API_manager.buy_stocks(symbol, abs(shares))
                print("-> Successfully bought", abs(shares), "of", symbol,".")
            except Exception as e:
                print("-> Buying", abs(shares), "of", symbol,"failed.")
                print(e)

# %%
interation = 1
while True:    
    print("*** Iteration", interation)
    update_utils() # update the utility global variables such as CUR_TIME
    update_stocks() # update the stock objects
    print("Current time is", CUR_TIME, ". The delayed time is", CUR_TIME_DELAYED)
    action_dict = bot_manager.make_decision()
    complete_actions(action_dict)
    time.sleep(60) #make decision every 60 seconds
    print(" ")
    interation +=1
# Out:
# *** Iteration 1
# Current time is 2021-06-16 16:19:13.741120+00:00 . The delayed time is 2021-06-16 16:03:13.741120+00:00
# --- No action performed at this time ---
#
# *** Iteration 2
# Current time is 2021-06-16 16:20:14.049486+00:00 . The delayed time is 2021-06-16 16:04:14.049486+00:00
# --- No action performed at this time ---
#
# *** Iteration 3
# Current time is 2021-06-16 16:21:14.346004+00:00 . The delayed time is 2021-06-16 16:05:14.346004+00:00
# --- No action performed at this time ---
#
# *** Iteration 4
# Current time is 2021-06-16 16:22:14.655698+00:00 . The delayed time is 2021-06-16 16:06:14.655698+00:00
# --- No action performed at this time ---
#
# *** Iteration 5
# Current time is 2021-06-16 16:23:15.002713+00:00 . The delayed time is 2021-06-16 16:07:15.002713+00:00
# --- No action performed at this time ---
#
# *** Iteration 6
# Current time is 2021-06-16 16:24:15.329220+00:00 . The delayed time is 2021-06-16 16:08:15.329220+00:00
# --- No action performed at this time ---
#
# *** Iteration 7
# Current time is 2021-06-16 16:25:15.615193+00:00 . The delayed time is 2021-06-16 16:09:15.615193+00:00
# --- No action performed at this time ---
#
# *** Iteration 44
# Current time is 2021-06-16 17:02:28.747794+00:00 . The delayed time is 2021-06-16 16:46:28.747794+00:00
# --- No action performed at this time ---
#
# *** Iteration 45
# Current time is 2021-06-16 17:03:29.106491+00:00 . The delayed time is 2021-06-16 16:47:29.106491+00:00
# -> Selling 1818 for 0 shares for $ 109.945 per share
# -> Selling 1818 of BILI failed.
# insufficient qty available for order (requested: 1818, available: 100)
#
# *** Iteration 46
# Current time is 2021-06-16 17:04:29.702601+00:00 . The delayed time is 2021-06-16 16:48:29.702601+00:00
# --- No action performed at this time ---
#
# *** Iteration 47
# Current time is 2021-06-16 17:05:30.007464+00:00 . The delayed time is 2021-06-16 16:49:30.007464+00:00
# --- No action performed at this time ---
#
# *** Iteration 48
# Current time is 2021-06-16 17:06:30.345123+00:00 . The delayed time is 2021-06-16 16:50:30.345123+00:00
# --- No action performed at this time ---
#
# *** Iteration 49
# Current time is 2021-06-16 17:07:30.798345+00:00 . The delayed time is 2021-06-16 16:51:30.798345+00:00
# --- No action performed at this time ---
#
# *** Iteration 50
# Current time is 2021-06-16 17:08:31.120806+00:00 . The delayed time is 2021-06-16 16:52:31.120806+00:00
# --- No action performed at this time ---
#
# *** Iteration 51
# Current time is 2021-06-16 17:09:31.448977+00:00 . The delayed time is 2021-06-16 16:53:31.448977+00:00
# --- No action performed at this time ---
#
# *** Iteration 52
# Current time is 2021-06-16 17:10:31.752327+00:00 . The delayed time is 2021-06-16 16:54:31.752327+00:00
# --- No action performed at this time ---
#
# *** Iteration 53
# Current time is 2021-06-16 17:11:32.071366+00:00 . The delayed time is 2021-06-16 16:55:32.071366+00:00
# --- No action performed at this time ---
#
# *** Iteration 54
# Current time is 2021-06-16 17:12:32.381669+00:00 . The delayed time is 2021-06-16 16:56:32.381669+00:00
# --- No action performed at this time ---
#
# *** Iteration 55
# Current time is 2021-06-16 17:13:32.688933+00:00 . The delayed time is 2021-06-16 16:57:32.688933+00:00
# --- No action performed at this time ---
#
# *** Iteration 56
# Current time is 2021-06-16 17:14:32.988393+00:00 . The delayed time is 2021-06-16 16:58:32.988393+00:00
# --- No action performed at this time ---
#
# *** Iteration 57
# Current time is 2021-06-16 17:15:33.295137+00:00 . The delayed time is 2021-06-16 16:59:33.295137+00:00
# --- No action performed at this time ---
#
# *** Iteration 58
# Current time is 2021-06-16 17:16:33.611083+00:00 . The delayed time is 2021-06-16 17:00:33.611083+00:00
# --- No action performed at this time ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-41b5231d8f33> in <module>
#       7     action_dict = bot_manager.make_decision()
#       8     complete_actions(action_dict)
# ----> 9     time.sleep(60) #make decision every 60 seconds
#      10     print(" ")
#      11     interation +=1
#
# KeyboardInterrupt:

# %%
#complete_actions({"BILI": 100})
# Out:
# -> Buying 100 of Badfalkdjf failed.
# could not find asset "Badfalkdjf"
