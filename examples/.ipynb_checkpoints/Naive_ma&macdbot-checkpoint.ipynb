# %% [markdown]
# ## This notebook walks through locally running mcad and ma bots using naive bot manager

# %%
# import necessary libaries 
# %reload_ext autoreload
# %autoreload 2
import os
os.chdir('..')

from scripts.apimanagers import APImanager
from scripts.assets import Account, Stock
from scripts.botmanagers import Stocks_manager_naive
from scripts.bots import Moving_average_bot, Macd_bot

import numpy as np
import pandas as pd
import alpaca_trade_api as tradeapi
from alpaca_trade_api.rest import TimeFrame
import datetime
import time

# %% [markdown]
# ### Initialization

# %%
# global variables
API_KEY = "PKI9JRCD2UOFVJTJEQ9Y"#<your API_KEY here>
SECRET_KEY = "JQAOBTno6yjE83Ks2tl8NpXnQEarMkMNrao1Hr0s"#<your SECRET_KEY here>
CUR_TIME_DELAYED = (datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(minutes=16))  # 16 minutes delay of current time for bars data
CUR_TIME = (datetime.datetime.now(datetime.timezone.utc))  # 15 minutes delay of current time for bars data
print(CUR_TIME_DELAYED)
# Out:
# 2021-06-16 16:01:22.753386+00:00

# %%
# create API manager
API_manager = APImanager(API_KEY, SECRET_KEY)

# %%
# get some past data for initialization. Let's look at APPL and AMD for this demonstration
hour_bar_apple, hour_bar_apple_t = API_manager.get_bar("AAPL", TimeFrame.Hour, "2021-06-08", CUR_TIME_DELAYED.astimezone().isoformat())
hour_bar_amd, hour_bar_amd_t = API_manager.get_bar("AMD", TimeFrame.Hour, "2021-06-08", CUR_TIME_DELAYED.astimezone().isoformat())
minute_bar_bili, minute_bar_bili_t = API_manager.get_bar("BILI", TimeFrame.Minute, (CUR_TIME_DELAYED - datetime.timedelta(minutes=500)).astimezone().isoformat(), CUR_TIME_DELAYED.astimezone().isoformat())

#get current price of the stock for initialization.
cur_price_apple = API_manager.get_price("AAPL")
cur_price_amd = API_manager.get_price("AMD")
cur_price_bili = API_manager.get_price("BILI")

#print(minute_bar_bili, cur_price_bili, minute_bar_bili_t)

# %%
# create stock objects
APPL_hour = Stock("AAPL", cur_price_apple, CUR_TIME_DELAYED, hour_bar_apple, TimeFrame.Hour, hour_bar_apple_t[0])
AMD_hour = Stock("AMD", cur_price_amd, CUR_TIME_DELAYED, hour_bar_amd, TimeFrame.Hour, hour_bar_amd_t[0])
BILI_minute = Stock("BILI", cur_price_bili, CUR_TIME_DELAYED, minute_bar_bili, TimeFrame.Minute, minute_bar_bili_t[0])
STOCKS = [APPL_hour, AMD_hour, BILI_minute]

# %%
# create bot objects. Give each bot let's say $200,000 asset for trading
BOT_AAPL_ma_hour = Moving_average_bot(APPL_hour, 200000)
BOT_AMD_macd_hour = Macd_bot(AMD_hour, 200000)
BOT_BILI_macd_minute = Macd_bot(BILI_minute, 200000)
BOTS = [BOT_AAPL_ma_hour, BOT_AMD_macd_hour, BOT_BILI_macd_minute]

# %%
# create the bot manager
bot_manager = Stocks_manager_naive(BOTS, None)

# %%
# print some prices for sanity check
APPL_hour.plot_price(25)
AMD_hour.plot_price(25)
BILI_minute.plot_price(25)

# %% [markdown]
# ### The Main Loop

# %%
def update_utils():
    global CUR_TIME_DELAYED, CUR_TIME
    CUR_TIME_DELAYED = (datetime.datetime.now(datetime.timezone.utc) - datetime.timedelta(minutes=16))  # 16 minutes delay of current time for bars data
    CUR_TIME = (datetime.datetime.now(datetime.timezone.utc))  # 15 minutes delay of current time for bars data

def update_stocks(passed_minutes = 15): # assumes 15 minutes has passed since the last update
    for s in STOCKS:
        symbol = s.symbol
        timeframe = s.timeframe
        cur_price = API_manager.get_price(symbol)
        bar, bar_t = API_manager.get_bar(symbol, timeframe, (CUR_TIME_DELAYED - datetime.timedelta(minutes=passed_minutes)).astimezone().isoformat(), CUR_TIME_DELAYED.astimezone().isoformat())
        #print(bar, bar_t)
        s.update(cur_price, bar, bar_t, CUR_TIME_DELAYED)

def complete_actions(action_dict):
    for symbol in action_dict.keys():
        shares = action_dict[symbol]
        if shares < 0:
            #sell
            try:
                API_manager.sell_stocks(symbol, abs(shares))
                print("-> Successfully sold", abs(shares), "of", symbol,".")
            except Exception as e:
                print("-> Selling", abs(shares), "of", symbol,"failed.")
                print(e)
        if shares > 0:
            #buy
            try:
                API_manager.buy_stocks(symbol, abs(shares))
                print("-> Successfully bought", abs(shares), "of", symbol,".")
            except Exception as e:
                print("-> Buying", abs(shares), "of", symbol,"failed.")
                print(e)

# %%
interation = 1
while True:    
    print("*** Iteration", interation)
    update_utils() # update the utility global variables such as CUR_TIME
    update_stocks() # update the stock objects
    print("Current time is", CUR_TIME, ". The delayed time is", CUR_TIME_DELAYED)
    action_dict = bot_manager.make_decision()
    complete_actions(action_dict)
    time.sleep(60) #make decision every 60 seconds
    print(" ")
    interation +=1
# Out:
# *** Iteration 1
# Current time is 2021-06-16 15:20:19.373795+00:00 . The delayed time is 2021-06-16 15:04:19.373795+00:00
# --- No action performed at this time ---
#
# *** Iteration 2
# Current time is 2021-06-16 15:21:19.716251+00:00 . The delayed time is 2021-06-16 15:05:19.716251+00:00
# --- No action performed at this time ---
#
# *** Iteration 3
# Current time is 2021-06-16 15:22:20.004908+00:00 . The delayed time is 2021-06-16 15:06:20.004908+00:00
# --- No action performed at this time ---
#
# *** Iteration 4
# Current time is 2021-06-16 15:23:20.313734+00:00 . The delayed time is 2021-06-16 15:07:20.313734+00:00
# --- No action performed at this time ---
#
# *** Iteration 5
# Current time is 2021-06-16 15:24:20.646735+00:00 . The delayed time is 2021-06-16 15:08:20.646735+00:00
# --- No action performed at this time ---
#
# *** Iteration 6
# Current time is 2021-06-16 15:25:21.074485+00:00 . The delayed time is 2021-06-16 15:09:21.074485+00:00
# --- No action performed at this time ---
#
# *** Iteration 7
# Current time is 2021-06-16 15:26:21.391186+00:00 . The delayed time is 2021-06-16 15:10:21.391186+00:00
# --- No action performed at this time ---
#
# *** Iteration 8
# Current time is 2021-06-16 15:27:21.838960+00:00 . The delayed time is 2021-06-16 15:11:21.838960+00:00
# --- No action performed at this time ---
#
# *** Iteration 9
# Current time is 2021-06-16 15:28:22.138006+00:00 . The delayed time is 2021-06-16 15:12:22.138006+00:00
# --- No action performed at this time ---
#
# *** Iteration 10
# Current time is 2021-06-16 15:29:22.449789+00:00 . The delayed time is 2021-06-16 15:13:22.449789+00:00
# --- No action performed at this time ---
#
# *** Iteration 11
# Current time is 2021-06-16 15:30:22.769983+00:00 . The delayed time is 2021-06-16 15:14:22.769983+00:00
# --- No action performed at this time ---
#
# *** Iteration 12
# Current time is 2021-06-16 15:31:23.080599+00:00 . The delayed time is 2021-06-16 15:15:23.080599+00:00
# --- No action performed at this time ---
#
# *** Iteration 13
# Current time is 2021-06-16 15:32:23.390337+00:00 . The delayed time is 2021-06-16 15:16:23.390337+00:00
# --- No action performed at this time ---
#
# *** Iteration 14
# Current time is 2021-06-16 15:33:23.790484+00:00 . The delayed time is 2021-06-16 15:17:23.790484+00:00
# --- No action performed at this time ---
#
# *** Iteration 15
# Current time is 2021-06-16 15:34:24.292876+00:00 . The delayed time is 2021-06-16 15:18:24.292876+00:00
# --- No action performed at this time ---
#
# *** Iteration 16
# Current time is 2021-06-16 15:35:24.791748+00:00 . The delayed time is 2021-06-16 15:19:24.791748+00:00
# --- No action performed at this time ---
#
# *** Iteration 17
# Current time is 2021-06-16 15:36:25.123836+00:00 . The delayed time is 2021-06-16 15:20:25.123836+00:00
# --- No action performed at this time ---
#
# *** Iteration 18
# Current time is 2021-06-16 15:37:25.446757+00:00 . The delayed time is 2021-06-16 15:21:25.446757+00:00
# --- No action performed at this time ---
#
# *** Iteration 19
# Current time is 2021-06-16 15:38:25.797137+00:00 . The delayed time is 2021-06-16 15:22:25.797137+00:00
# --- No action performed at this time ---
#
# *** Iteration 20
# Current time is 2021-06-16 15:39:39.321994+00:00 . The delayed time is 2021-06-16 15:23:39.321994+00:00
# --- No action performed at this time ---
#
# *** Iteration 21
# Current time is 2021-06-16 15:40:39.691631+00:00 . The delayed time is 2021-06-16 15:24:39.691631+00:00
# --- No action performed at this time ---
#
# *** Iteration 22
# Current time is 2021-06-16 15:41:40.043939+00:00 . The delayed time is 2021-06-16 15:25:40.043939+00:00
# --- No action performed at this time ---
#
# *** Iteration 23
# Current time is 2021-06-16 15:42:40.379606+00:00 . The delayed time is 2021-06-16 15:26:40.379606+00:00
# --- No action performed at this time ---
#
# *** Iteration 24
# Current time is 2021-06-16 15:43:40.685719+00:00 . The delayed time is 2021-06-16 15:27:40.685719+00:00
# --- No action performed at this time ---
#
# *** Iteration 25
# Current time is 2021-06-16 15:44:41.040216+00:00 . The delayed time is 2021-06-16 15:28:41.040216+00:00
# -> buying BILI for 1822 shares for $ 109.73 per share
# -> Buying 1822 of BILI failed.
#
# *** Iteration 26
# Current time is 2021-06-16 15:45:41.681335+00:00 . The delayed time is 2021-06-16 15:29:41.681335+00:00
# -> Selling 1822 for 0 shares for $ 109.73 per share
# -> Selling 1822 of BILI failed.
#
# *** Iteration 27
# Current time is 2021-06-16 15:46:42.097998+00:00 . The delayed time is 2021-06-16 15:30:42.097998+00:00
# --- No action performed at this time ---
#
# *** Iteration 28
# Current time is 2021-06-16 15:47:42.416361+00:00 . The delayed time is 2021-06-16 15:31:42.416361+00:00
# -> buying BILI for 1816 shares for $ 110.09 per share
# -> Buying 1816 of BILI failed.
#
# *** Iteration 29
# Current time is 2021-06-16 15:48:43.097140+00:00 . The delayed time is 2021-06-16 15:32:43.097140+00:00
# --- No action performed at this time ---
#
# *** Iteration 30
# Current time is 2021-06-16 15:49:43.397928+00:00 . The delayed time is 2021-06-16 15:33:43.397928+00:00
# --- No action performed at this time ---
#
# *** Iteration 31
# Current time is 2021-06-16 15:50:43.909920+00:00 . The delayed time is 2021-06-16 15:34:43.908919+00:00
# --- No action performed at this time ---
#
# *** Iteration 32
# Current time is 2021-06-16 15:51:44.271655+00:00 . The delayed time is 2021-06-16 15:35:44.271655+00:00
# --- No action performed at this time ---
#
# *** Iteration 33
# Current time is 2021-06-16 15:52:44.789583+00:00 . The delayed time is 2021-06-16 15:36:44.789583+00:00
# --- No action performed at this time ---
#
# *** Iteration 34
# Current time is 2021-06-16 15:53:45.180850+00:00 . The delayed time is 2021-06-16 15:37:45.180850+00:00
# --- No action performed at this time ---
#
# *** Iteration 35
# Current time is 2021-06-16 15:54:45.499940+00:00 . The delayed time is 2021-06-16 15:38:45.499940+00:00
# --- No action performed at this time ---
#
# *** Iteration 36
# Current time is 2021-06-16 15:55:45.834496+00:00 . The delayed time is 2021-06-16 15:39:45.834496+00:00
# --- No action performed at this time ---
#
# *** Iteration 37
# Current time is 2021-06-16 15:56:46.133473+00:00 . The delayed time is 2021-06-16 15:40:46.133473+00:00
# --- No action performed at this time ---
#
# *** Iteration 38
# Current time is 2021-06-16 15:57:46.446396+00:00 . The delayed time is 2021-06-16 15:41:46.446396+00:00
# --- No action performed at this time ---
#
# *** Iteration 39
# Current time is 2021-06-16 15:58:46.786751+00:00 . The delayed time is 2021-06-16 15:42:46.786751+00:00
# --- No action performed at this time ---
#
# *** Iteration 40
# Current time is 2021-06-16 15:59:47.120853+00:00 . The delayed time is 2021-06-16 15:43:47.120853+00:00
# --- No action performed at this time ---
#
# *** Iteration 41
# Current time is 2021-06-16 16:00:47.461420+00:00 . The delayed time is 2021-06-16 15:44:47.461420+00:00
# --- No action performed at this time ---
#
# *** Iteration 42
# Current time is 2021-06-16 16:01:47.749286+00:00 . The delayed time is 2021-06-16 15:45:47.749286+00:00
# --- No action performed at this time ---
#
# *** Iteration 43
# Current time is 2021-06-16 16:02:48.128840+00:00 . The delayed time is 2021-06-16 15:46:48.128840+00:00
# --- No action performed at this time ---
#
# *** Iteration 44
# Current time is 2021-06-16 16:03:48.432749+00:00 . The delayed time is 2021-06-16 15:47:48.432749+00:00
# --- No action performed at this time ---
#
# *** Iteration 45
# Current time is 2021-06-16 16:04:48.744372+00:00 . The delayed time is 2021-06-16 15:48:48.744372+00:00
# --- No action performed at this time ---
#
# *** Iteration 46
# Current time is 2021-06-16 16:05:49.051347+00:00 . The delayed time is 2021-06-16 15:49:49.051347+00:00
# --- No action performed at this time ---
#
# *** Iteration 47
# Current time is 2021-06-16 16:06:49.368441+00:00 . The delayed time is 2021-06-16 15:50:49.368441+00:00
# --- No action performed at this time ---
#
# *** Iteration 48
# Current time is 2021-06-16 16:07:49.649385+00:00 . The delayed time is 2021-06-16 15:51:49.649385+00:00
# --- No action performed at this time ---
#
# *** Iteration 49
# Current time is 2021-06-16 16:08:50.082074+00:00 . The delayed time is 2021-06-16 15:52:50.082074+00:00
# --- No action performed at this time ---
#
# *** Iteration 50
# Current time is 2021-06-16 16:09:50.405729+00:00 . The delayed time is 2021-06-16 15:53:50.405729+00:00
# --- No action performed at this time ---
#
# *** Iteration 51
# Current time is 2021-06-16 16:10:50.853412+00:00 . The delayed time is 2021-06-16 15:54:50.853412+00:00
# --- No action performed at this time ---
#
# *** Iteration 52
# Current time is 2021-06-16 16:11:51.143269+00:00 . The delayed time is 2021-06-16 15:55:51.143269+00:00
# --- No action performed at this time ---
#
# *** Iteration 53
# Current time is 2021-06-16 16:12:51.436297+00:00 . The delayed time is 2021-06-16 15:56:51.436297+00:00
# --- No action performed at this time ---
#
# *** Iteration 54
# Current time is 2021-06-16 16:13:51.728835+00:00 . The delayed time is 2021-06-16 15:57:51.728835+00:00
# --- No action performed at this time ---
#
# *** Iteration 55
# Current time is 2021-06-16 16:14:51.995702+00:00 . The delayed time is 2021-06-16 15:58:51.995702+00:00
# --- No action performed at this time ---

# %%
#complete_actions({"BILI": 100})
# Out:
# -> Buying 100 of Badfalkdjf failed.
# could not find asset "Badfalkdjf"
